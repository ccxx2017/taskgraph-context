# %% [markdown]
# ```mermaid
# flowchart TB
#     subgraph CTX["上下文窗口（200K tokens）"]
#         direction LR
#
#         subgraph A["固定开销"]
#             A1["System Prompt"]
#             A2["+ 工具 Schema"]
#         end
#
#         subgraph B["可变开销"]
#             B1["消息历史"]
#             B2["工具调用/结果"]
#             B3["Thinking blocks"]
#         end
#
#         subgraph C["净空间"]
#             C1["输出预留"]
#             C2["20K tokens"]
#         end
#     end
#
#     A_note["不可压缩"]
#     B_note["可压缩，是主战场"]
#     C_note["不可碰"]
#
#     A --- A_note
#     B --- B_note
#     C --- C_note
